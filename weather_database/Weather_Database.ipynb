# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-90.000, high=90.000, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 739

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2fed0b437b047468dcae844319ee547c

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, 
        #and weather description
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Weather Description": city_description})
            
            

    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | punta arenas
# Processing Record 2 of Set 1 | dujuma
# City not found. Skipping...
# Processing Record 3 of Set 1 | sinkat
# City not found. Skipping...
# Processing Record 4 of Set 1 | busselton
# Processing Record 5 of Set 1 | ushuaia
# Processing Record 6 of Set 1 | qaanaaq
# Processing Record 7 of Set 1 | beira
# Processing Record 8 of Set 1 | hwange
# Processing Record 9 of Set 1 | tournon-sur-rhone
# Processing Record 10 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 11 of Set 1 | marzuq
# Processing Record 12 of Set 1 | bredasdorp
# Processing Record 13 of Set 1 | voyvozh
# Processing Record 14 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 15 of Set 1 | kalmunai
# Processing Record 16 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 17 of Set 1 | balkanabat
# Processing Record 18 of Set 1 | tiznit
# Processing Record 19 of Set 1 | saint-ambroise
# Processing Record 20 of Set 1 | gonbad-e qabus
# Processing Record 21 of Set 1 | kruisfontein
# Processing Record 22 of Set 1 | arzgir
# Processing Record 23 of Set 1 | tasiilaq
# Processing Record 24 of Set 1 | bandarbeyla
# Processing Record 25 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 26 of Set 1 | osakarovka
# Processing Record 27 of Set 1 | sal rei
# Processing Record 28 of Set 1 | nanortalik
# Processing Record 29 of Set 1 | cape town
# Processing Record 30 of Set 1 | hithadhoo
# Processing Record 31 of Set 1 | havre-saint-pierre
# Processing Record 32 of Set 1 | saint-philippe
# Processing Record 33 of Set 1 | pangody
# Processing Record 34 of Set 1 | jamestown
# Processing Record 35 of Set 1 | saldanha
# Processing Record 36 of Set 1 | barra do garcas
# Processing Record 37 of Set 1 | hermanus
# Processing Record 38 of Set 1 | taoudenni
# Processing Record 39 of Set 1 | inderborskiy
# City not found. Skipping...
# Processing Record 40 of Set 1 | faya
# Processing Record 41 of Set 1 | victoria
# Processing Record 42 of Set 1 | marcona
# City not found. Skipping...
# Processing Record 43 of Set 1 | maraba
# Processing Record 44 of Set 1 | umzimvubu
# City not found. Skipping...
# Processing Record 45 of Set 1 | constantine
# Processing Record 46 of Set 1 | dikson
# Processing Record 47 of Set 1 | kletskaya
# Processing Record 48 of Set 1 | kostomuksha
# Processing Record 49 of Set 1 | yarada
# Processing Record 50 of Set 1 | arraial do cabo
# Processing Record 1 of Set 2 | mendi
# Processing Record 2 of Set 2 | nouadhibou
# Processing Record 3 of Set 2 | florianopolis
# Processing Record 4 of Set 2 | hofn
# Processing Record 5 of Set 2 | iguape
# Processing Record 6 of Set 2 | cidreira
# Processing Record 7 of Set 2 | toamasina
# Processing Record 8 of Set 2 | aquiraz
# Processing Record 9 of Set 2 | acarau
# Processing Record 10 of Set 2 | clyde river
# Processing Record 11 of Set 2 | kiomboi
# Processing Record 12 of Set 2 | camacha
# Processing Record 13 of Set 2 | bani
# Processing Record 14 of Set 2 | makat
# Processing Record 15 of Set 2 | namibe
# Processing Record 16 of Set 2 | ambilobe
# Processing Record 17 of Set 2 | ozgon
# City not found. Skipping...
# Processing Record 18 of Set 2 | tambul
# City not found. Skipping...
# Processing Record 19 of Set 2 | ponta delgada
# Processing Record 20 of Set 2 | georgetown
# Processing Record 21 of Set 2 | port alfred
# Processing Record 22 of Set 2 | malangali
# Processing Record 23 of Set 2 | east london
# Processing Record 24 of Set 2 | mega
# Processing Record 25 of Set 2 | lasa
# Processing Record 26 of Set 2 | qaqortoq
# Processing Record 27 of Set 2 | tshela
# Processing Record 28 of Set 2 | aksarka
# Processing Record 29 of Set 2 | bokspits
# City not found. Skipping...
# Processing Record 30 of Set 2 | souillac
# Processing Record 31 of Set 2 | saint-francois
# Processing Record 32 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 33 of Set 2 | dzhusaly
# City not found. Skipping...
# Processing Record 34 of Set 2 | sarny
# Processing Record 35 of Set 2 | chuy
# Processing Record 36 of Set 2 | porto belo
# Processing Record 37 of Set 2 | kandiaro
# Processing Record 38 of Set 2 | ribeira grande
# Processing Record 39 of Set 2 | itarema
# Processing Record 40 of Set 2 | cherdyn
# Processing Record 41 of Set 2 | lagoa
# Processing Record 42 of Set 2 | guiratinga
# Processing Record 43 of Set 2 | khiv
# Processing Record 44 of Set 2 | mahebourg
# Processing Record 45 of Set 2 | bengkulu
# Processing Record 46 of Set 2 | gamboula
# Processing Record 47 of Set 2 | cuamba
# Processing Record 48 of Set 2 | coquimbo
# Processing Record 49 of Set 2 | xuddur
# Processing Record 50 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 1 of Set 3 | de aar
# Processing Record 2 of Set 3 | lar
# Processing Record 3 of Set 3 | richards bay
# Processing Record 4 of Set 3 | marsa matruh
# Processing Record 5 of Set 3 | bambous virieux
# Processing Record 6 of Set 3 | vardo
# Processing Record 7 of Set 3 | mizdah
# Processing Record 8 of Set 3 | port elizabeth
# Processing Record 9 of Set 3 | alta floresta
# Processing Record 10 of Set 3 | porto walter
# Processing Record 11 of Set 3 | santa marta
# Processing Record 12 of Set 3 | san antero
# Processing Record 13 of Set 3 | cayenne
# Processing Record 14 of Set 3 | poli
# Processing Record 15 of Set 3 | floro
# Processing Record 16 of Set 3 | ilulissat
# Processing Record 17 of Set 3 | zhanatas
# City not found. Skipping...
# Processing Record 18 of Set 3 | maceio
# Processing Record 19 of Set 3 | ouricuri
# Processing Record 20 of Set 3 | soyo
# Processing Record 21 of Set 3 | tarudant
# City not found. Skipping...
# Processing Record 22 of Set 3 | gravdal
# Processing Record 23 of Set 3 | longyearbyen
# Processing Record 24 of Set 3 | molina
# Processing Record 25 of Set 3 | muzhi
# Processing Record 26 of Set 3 | north adams
# Processing Record 27 of Set 3 | luderitz
# Processing Record 28 of Set 3 | sao filipe
# Processing Record 29 of Set 3 | tabriz
# Processing Record 30 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 31 of Set 3 | kampene
# Processing Record 32 of Set 3 | dingle
# Processing Record 33 of Set 3 | shiloh
# Processing Record 34 of Set 3 | bereda
# Processing Record 35 of Set 3 | brighton
# Processing Record 36 of Set 3 | leh
# Processing Record 37 of Set 3 | straumen
# Processing Record 38 of Set 3 | san cristobal
# Processing Record 39 of Set 3 | tawzar
# City not found. Skipping...
# Processing Record 40 of Set 3 | dulce nombre de culmi
# Processing Record 41 of Set 3 | upernavik
# Processing Record 42 of Set 3 | gat
# Processing Record 43 of Set 3 | alizai
# Processing Record 44 of Set 3 | narsaq
# Processing Record 45 of Set 3 | guajara-mirim
# City not found. Skipping...
# Processing Record 46 of Set 3 | cabedelo
# Processing Record 47 of Set 3 | albany
# Processing Record 48 of Set 3 | cap malheureux
# Processing Record 49 of Set 3 | ratne
# Processing Record 50 of Set 3 | wilmington
# Processing Record 1 of Set 4 | mumford
# Processing Record 2 of Set 4 | nata
# Processing Record 3 of Set 4 | mikhaylov
# Processing Record 4 of Set 4 | urengoy
# Processing Record 5 of Set 4 | labytnangi
# Processing Record 6 of Set 4 | ancud
# Processing Record 7 of Set 4 | tafresh
# Processing Record 8 of Set 4 | vila velha
# Processing Record 9 of Set 4 | saint-augustin
# Processing Record 10 of Set 4 | delta del tigre
# Processing Record 11 of Set 4 | bonthe
# Processing Record 12 of Set 4 | stornoway
# Processing Record 13 of Set 4 | olavarria
# Processing Record 14 of Set 4 | lulea
# Processing Record 15 of Set 4 | buraydah
# Processing Record 16 of Set 4 | rio gallegos
# Processing Record 17 of Set 4 | mamallapuram
# Processing Record 18 of Set 4 | anloga
# Processing Record 19 of Set 4 | plettenberg bay
# Processing Record 20 of Set 4 | pafos
# Processing Record 21 of Set 4 | cherkessk
# Processing Record 22 of Set 4 | tumannyy
# City not found. Skipping...
# Processing Record 23 of Set 4 | taltal
# Processing Record 24 of Set 4 | barranquilla
# Processing Record 25 of Set 4 | karkaralinsk
# City not found. Skipping...
# Processing Record 26 of Set 4 | adrar
# Processing Record 27 of Set 4 | tsabong
# Processing Record 28 of Set 4 | warqla
# City not found. Skipping...
# Processing Record 29 of Set 4 | yenagoa
# Processing Record 30 of Set 4 | fomboni
# Processing Record 31 of Set 4 | sept-iles
# Processing Record 32 of Set 4 | iqaluit
# Processing Record 33 of Set 4 | klaksvik
# Processing Record 34 of Set 4 | caravelas
# Processing Record 35 of Set 4 | khomutovka
# Processing Record 36 of Set 4 | san ramon
# Processing Record 37 of Set 4 | brae
# Processing Record 38 of Set 4 | moth
# Processing Record 39 of Set 4 | sucua
# Processing Record 40 of Set 4 | mecca
# Processing Record 41 of Set 4 | fort-shevchenko
# Processing Record 42 of Set 4 | oistins
# Processing Record 43 of Set 4 | muros
# Processing Record 44 of Set 4 | mezen
# Processing Record 45 of Set 4 | suruc
# Processing Record 46 of Set 4 | yar-sale
# Processing Record 47 of Set 4 | kholm-zhirkovskiy
# Processing Record 48 of Set 4 | bosansko grahovo
# Processing Record 49 of Set 4 | mar del plata
# Processing Record 50 of Set 4 | corinto
# Processing Record 1 of Set 5 | maniitsoq
# Processing Record 2 of Set 5 | shiraz
# Processing Record 3 of Set 5 | sur
# Processing Record 4 of Set 5 | hamilton
# Processing Record 5 of Set 5 | shahrud
# Processing Record 6 of Set 5 | bocana de paiwas
# Processing Record 7 of Set 5 | damghan
# Processing Record 8 of Set 5 | ponta do sol
# Processing Record 9 of Set 5 | thompson
# Processing Record 10 of Set 5 | eresos
# Processing Record 11 of Set 5 | grande-riviere
# City not found. Skipping...
# Processing Record 12 of Set 5 | abha
# Processing Record 13 of Set 5 | roanoke rapids
# Processing Record 14 of Set 5 | benghazi
# Processing Record 15 of Set 5 | coro
# Processing Record 16 of Set 5 | remontnoye
# Processing Record 17 of Set 5 | quelimane
# Processing Record 18 of Set 5 | velka bites
# Processing Record 19 of Set 5 | umm lajj
# Processing Record 20 of Set 5 | vila franca do campo
# Processing Record 21 of Set 5 | kingussie
# Processing Record 22 of Set 5 | polyarnyy
# Processing Record 23 of Set 5 | rolim de moura
# City not found. Skipping...
# Processing Record 24 of Set 5 | cozumel
# Processing Record 25 of Set 5 | olafsvik
# Processing Record 26 of Set 5 | snezhnogorsk
# Processing Record 27 of Set 5 | loubomo
# Processing Record 28 of Set 5 | tandalti
# Processing Record 29 of Set 5 | vestmanna
# Processing Record 30 of Set 5 | basqal
# Processing Record 31 of Set 5 | harare
# Processing Record 32 of Set 5 | obera
# Processing Record 33 of Set 5 | saint-pierre
# Processing Record 34 of Set 5 | tucurui
# Processing Record 35 of Set 5 | tromso
# Processing Record 36 of Set 5 | pitimbu
# Processing Record 37 of Set 5 | saint george
# Processing Record 38 of Set 5 | touros
# Processing Record 39 of Set 5 | cockburn town
# Processing Record 40 of Set 5 | chake chake
# Processing Record 41 of Set 5 | bur gabo
# City not found. Skipping...
# Processing Record 42 of Set 5 | mana
# Processing Record 43 of Set 5 | qasigiannguit
# Processing Record 44 of Set 5 | campos gerais
# Processing Record 45 of Set 5 | nioro
# Processing Record 46 of Set 5 | kanniyakumari
# Processing Record 47 of Set 5 | novooleksiyivka
# Processing Record 48 of Set 5 | araouane
# Processing Record 49 of Set 5 | nadym
# Processing Record 50 of Set 5 | san jose
# Processing Record 1 of Set 6 | lucapa
# Processing Record 2 of Set 6 | havoysund
# Processing Record 3 of Set 6 | dourbali
# Processing Record 4 of Set 6 | paita
# Processing Record 5 of Set 6 | grimari
# City not found. Skipping...
# Processing Record 6 of Set 6 | maxixe
# Processing Record 7 of Set 6 | beloha
# Processing Record 8 of Set 6 | teberda
# Processing Record 9 of Set 6 | semey
# Processing Record 10 of Set 6 | sao raimundo nonato
# Processing Record 11 of Set 6 | necochea
# Processing Record 12 of Set 6 | maloshuyka
# City not found. Skipping...
# Processing Record 13 of Set 6 | hrodna
# Processing Record 14 of Set 6 | le mans
# Processing Record 15 of Set 6 | mucurapo
# Processing Record 16 of Set 6 | bentiu
# Processing Record 17 of Set 6 | vestmannaeyjar
# Processing Record 18 of Set 6 | yining
# Processing Record 19 of Set 6 | kudymkar
# Processing Record 20 of Set 6 | tsihombe
# City not found. Skipping...
# Processing Record 21 of Set 6 | iznik
# Processing Record 22 of Set 6 | saint anthony
# Processing Record 23 of Set 6 | kulhudhuffushi
# Processing Record 24 of Set 6 | cravo norte
# Processing Record 25 of Set 6 | waddan
# Processing Record 26 of Set 6 | liberia
# Processing Record 27 of Set 6 | havelock
# Processing Record 28 of Set 6 | itacoatiara
# Processing Record 29 of Set 6 | catamarca
# Processing Record 30 of Set 6 | kemin
# Processing Record 31 of Set 6 | mehamn
# Processing Record 32 of Set 6 | stromness
# Processing Record 33 of Set 6 | salalah
# Processing Record 34 of Set 6 | blagoyevo
# Processing Record 35 of Set 6 | tuysarkan
# City not found. Skipping...
# Processing Record 36 of Set 6 | bargal
# City not found. Skipping...
# Processing Record 37 of Set 6 | adria
# Processing Record 38 of Set 6 | ojhar
# Processing Record 39 of Set 6 | youkounkoun
# Processing Record 40 of Set 6 | awjilah
# Processing Record 41 of Set 6 | nchelenge
# Processing Record 42 of Set 6 | kyshtovka
# Processing Record 43 of Set 6 | beterou
# Processing Record 44 of Set 6 | kasangulu
# Processing Record 45 of Set 6 | am timan
# Processing Record 46 of Set 6 | piacabucu
# Processing Record 47 of Set 6 | barentu
# Processing Record 48 of Set 6 | bajil
# Processing Record 49 of Set 6 | castro
# Processing Record 50 of Set 6 | great yarmouth
# Processing Record 1 of Set 7 | marsh harbour
# Processing Record 2 of Set 7 | sao felix do xingu
# Processing Record 3 of Set 7 | pangnirtung
# Processing Record 4 of Set 7 | asosa
# Processing Record 5 of Set 7 | spetsai
# City not found. Skipping...
# Processing Record 6 of Set 7 | atar
# Processing Record 7 of Set 7 | bereslavka
# Processing Record 8 of Set 7 | benguela
# Processing Record 9 of Set 7 | dobryanka
# Processing Record 10 of Set 7 | kamina
# Processing Record 11 of Set 7 | monrovia
# Processing Record 12 of Set 7 | chimbarongo
# Processing Record 13 of Set 7 | polonnaruwa
# Processing Record 14 of Set 7 | roald
# Processing Record 15 of Set 7 | torbay
# Processing Record 16 of Set 7 | guaranesia
# Processing Record 17 of Set 7 | scalloway
# City not found. Skipping...
# Processing Record 18 of Set 7 | luanda
# Processing Record 19 of Set 7 | nova varos
# Processing Record 20 of Set 7 | sao jose do belmonte
# Processing Record 21 of Set 7 | oum hadjer
# Processing Record 22 of Set 7 | kommunarka
# Processing Record 23 of Set 7 | beni suef
# Processing Record 24 of Set 7 | husavik
# Processing Record 25 of Set 7 | sfantu gheorghe
# Processing Record 26 of Set 7 | iglino
# Processing Record 27 of Set 7 | copiapo
# Processing Record 28 of Set 7 | jalingo
# Processing Record 29 of Set 7 | knysna
# Processing Record 30 of Set 7 | menongue
# Processing Record 31 of Set 7 | sadon
# Processing Record 32 of Set 7 | codrington
# Processing Record 33 of Set 7 | urumqi
# Processing Record 34 of Set 7 | krasnoselkup
# Processing Record 35 of Set 7 | henties bay
# Processing Record 36 of Set 7 | duba-yurt
# Processing Record 37 of Set 7 | norden
# Processing Record 38 of Set 7 | muli
# Processing Record 39 of Set 7 | odweyne
# Processing Record 40 of Set 7 | laguna
# Processing Record 41 of Set 7 | geraldton
# Processing Record 42 of Set 7 | arona
# Processing Record 43 of Set 7 | grand gaube
# Processing Record 44 of Set 7 | omboue
# Processing Record 45 of Set 7 | asyut
# Processing Record 46 of Set 7 | veraval
# Processing Record 47 of Set 7 | salto
# Processing Record 48 of Set 7 | azanka
# Processing Record 49 of Set 7 | antofagasta
# Processing Record 50 of Set 7 | kazalinsk
# City not found. Skipping...
# Processing Record 1 of Set 8 | aswan
# Processing Record 2 of Set 8 | sechura
# Processing Record 3 of Set 8 | hobyo
# Processing Record 4 of Set 8 | severodvinsk
# Processing Record 5 of Set 8 | gamba
# Processing Record 6 of Set 8 | porto santo
# Processing Record 7 of Set 8 | tabuk
# Processing Record 8 of Set 8 | mezhdurechensk
# Processing Record 9 of Set 8 | beaufort
# Processing Record 10 of Set 8 | elizabeth city
# Processing Record 11 of Set 8 | matara
# Processing Record 12 of Set 8 | savinka
# Processing Record 13 of Set 8 | sao joao da barra
# Processing Record 14 of Set 8 | arvika
# Processing Record 15 of Set 8 | glace bay
# Processing Record 16 of Set 8 | khash
# Processing Record 17 of Set 8 | santa ana
# Processing Record 18 of Set 8 | comodoro rivadavia
# Processing Record 19 of Set 8 | marseille
# Processing Record 20 of Set 8 | kirovskiy
# Processing Record 21 of Set 8 | margate
# Processing Record 22 of Set 8 | beeskow
# Processing Record 23 of Set 8 | maridi
# Processing Record 24 of Set 8 | paamiut
# Processing Record 25 of Set 8 | sebastian
# Processing Record 26 of Set 8 | bilma
# Processing Record 27 of Set 8 | kavaratti
# Processing Record 28 of Set 8 | morros
# Processing Record 29 of Set 8 | ilebo
# Processing Record 30 of Set 8 | coihaique
# Processing Record 31 of Set 8 | sisimiut
# Processing Record 32 of Set 8 | dhrol
# Processing Record 33 of Set 8 | watsa
# Processing Record 34 of Set 8 | mogadishu
# Processing Record 35 of Set 8 | solton
# Processing Record 36 of Set 8 | kjollefjord
# Processing Record 37 of Set 8 | prainha
# Processing Record 38 of Set 8 | eatonton
# Processing Record 39 of Set 8 | buriti bravo
# Processing Record 40 of Set 8 | weilmunster
# Processing Record 41 of Set 8 | puerto madryn
# Processing Record 42 of Set 8 | praia da vitoria
# Processing Record 43 of Set 8 | revda
# Processing Record 44 of Set 8 | frederikshavn
# Processing Record 45 of Set 8 | lima
# Processing Record 46 of Set 8 | bathsheba
# Processing Record 47 of Set 8 | port hawkesbury
# Processing Record 48 of Set 8 | sembe
# Processing Record 49 of Set 8 | saint-joseph
# Processing Record 50 of Set 8 | kabompo
# Processing Record 1 of Set 9 | bubaque
# Processing Record 2 of Set 9 | gazli
# Processing Record 3 of Set 9 | sandy bay
# Processing Record 4 of Set 9 | mbini
# Processing Record 5 of Set 9 | ndele
# Processing Record 6 of Set 9 | kudahuvadhoo
# Processing Record 7 of Set 9 | pontes e lacerda
# Processing Record 8 of Set 9 | loiza
# Processing Record 9 of Set 9 | camiri
# Processing Record 10 of Set 9 | ostrovnoy
# Processing Record 11 of Set 9 | ballina
# Processing Record 12 of Set 9 | varna
# Processing Record 13 of Set 9 | shirvan
# Processing Record 14 of Set 9 | maragogi
# Processing Record 15 of Set 9 | upata
# Processing Record 16 of Set 9 | lebu
# Processing Record 17 of Set 9 | korla
# Processing Record 18 of Set 9 | takestan
# Processing Record 19 of Set 9 | kindu
# Processing Record 20 of Set 9 | gornopravdinsk
# Processing Record 21 of Set 9 | kupino
# Processing Record 22 of Set 9 | apen
# Processing Record 23 of Set 9 | bosaso
# Processing Record 24 of Set 9 | grevena
# Processing Record 25 of Set 9 | uhlove
# Processing Record 26 of Set 9 | sistranda
# Processing Record 27 of Set 9 | rafaela
# Processing Record 28 of Set 9 | dzaoudzi
# Processing Record 29 of Set 9 | loandjili
# Processing Record 30 of Set 9 | maykain
# City not found. Skipping...
# Processing Record 31 of Set 9 | kirkwall
# Processing Record 32 of Set 9 | ostersund
# Processing Record 33 of Set 9 | liverpool
# Processing Record 34 of Set 9 | santa maria
# Processing Record 35 of Set 9 | boa vista
# Processing Record 36 of Set 9 | marrakesh
# Processing Record 37 of Set 9 | ayia galini
# Processing Record 38 of Set 9 | presidencia roque saenz pena
# Processing Record 39 of Set 9 | les escoumins
# Processing Record 40 of Set 9 | berbera
# Processing Record 41 of Set 9 | fallingbostel
# Processing Record 42 of Set 9 | krasnoye
# Processing Record 43 of Set 9 | karaul
# City not found. Skipping...
# Processing Record 44 of Set 9 | estelle
# Processing Record 45 of Set 9 | santa rosa de osos
# Processing Record 46 of Set 9 | strezhevoy
# Processing Record 47 of Set 9 | savonlinna
# Processing Record 48 of Set 9 | deh rawud
# City not found. Skipping...
# Processing Record 49 of Set 9 | muravlenko
# Processing Record 50 of Set 9 | longlac
# City not found. Skipping...
# Processing Record 1 of Set 10 | iranshahr
# Processing Record 2 of Set 10 | caraballeda
# Processing Record 3 of Set 10 | sydney
# Processing Record 4 of Set 10 | grindavik
# Processing Record 5 of Set 10 | sabha
# Processing Record 6 of Set 10 | hatillo
# Processing Record 7 of Set 10 | quatre cocos
# Processing Record 8 of Set 10 | san pedro
# Processing Record 9 of Set 10 | assare
# Processing Record 10 of Set 10 | astana
# Processing Record 11 of Set 10 | praia
# Processing Record 12 of Set 10 | usinsk
# Processing Record 13 of Set 10 | joshimath
# Processing Record 14 of Set 10 | telfs
# Processing Record 15 of Set 10 | pervomayskoye
# Processing Record 16 of Set 10 | palmas
# Processing Record 17 of Set 10 | carnarvon
# Processing Record 18 of Set 10 | skalistyy
# City not found. Skipping...
# Processing Record 19 of Set 10 | ringebu
# Processing Record 20 of Set 10 | porto novo
# Processing Record 21 of Set 10 | louisbourg
# City not found. Skipping...
# Processing Record 22 of Set 10 | hambantota
# Processing Record 23 of Set 10 | talcahuano
# Processing Record 24 of Set 10 | tocopilla
# Processing Record 25 of Set 10 | saint-martin-boulogne
# Processing Record 26 of Set 10 | kabelvag
# Processing Record 27 of Set 10 | kargalinskaya
# Processing Record 28 of Set 10 | goderich
# Processing Record 29 of Set 10 | rawson
# Processing Record 30 of Set 10 | lincoln
# Processing Record 31 of Set 10 | toguchin
# Processing Record 32 of Set 10 | mansa
# Processing Record 33 of Set 10 | belmonte
# Processing Record 34 of Set 10 | banmankhi
# Processing Record 35 of Set 10 | marawi
# Processing Record 36 of Set 10 | kutum
# Processing Record 37 of Set 10 | birao
# Processing Record 38 of Set 10 | rocha
# Processing Record 39 of Set 10 | mazagao
# Processing Record 40 of Set 10 | saint-paul
# Processing Record 41 of Set 10 | bay roberts
# Processing Record 42 of Set 10 | bolungarvik
# City not found. Skipping...
# Processing Record 43 of Set 10 | surt
# Processing Record 44 of Set 10 | lichinga
# Processing Record 45 of Set 10 | crab hill
# City not found. Skipping...
# Processing Record 46 of Set 10 | morondava
# Processing Record 47 of Set 10 | mitsamiouli
# Processing Record 48 of Set 10 | coruripe
# Processing Record 49 of Set 10 | borovskoy
# Processing Record 50 of Set 10 | garoua
# Processing Record 1 of Set 11 | tarko-sale
# Processing Record 2 of Set 11 | tamandare
# Processing Record 3 of Set 11 | rundu
# Processing Record 4 of Set 11 | krasnoborsk
# Processing Record 5 of Set 11 | cockburn harbour
# City not found. Skipping...
# Processing Record 6 of Set 11 | lohardaga
# Processing Record 7 of Set 11 | mount pleasant
# Processing Record 8 of Set 11 | shchuchye
# City not found. Skipping...
# Processing Record 9 of Set 11 | boromo
# Processing Record 10 of Set 11 | kourou
# Processing Record 11 of Set 11 | nara
# Processing Record 12 of Set 11 | malakal
# Processing Record 13 of Set 11 | baripada
# Processing Record 14 of Set 11 | ayacucho
# Processing Record 15 of Set 11 | puerto carreno
# Processing Record 16 of Set 11 | lyngseidet
# Processing Record 17 of Set 11 | cururupu
# Processing Record 18 of Set 11 | imeni karla libknekhta
# Processing Record 19 of Set 11 | bolvasnita
# City not found. Skipping...
# Processing Record 20 of Set 11 | sambava
# Processing Record 21 of Set 11 | vallenar
# Processing Record 22 of Set 11 | beaupre
# Processing Record 23 of Set 11 | ugoofaaru
# Processing Record 24 of Set 11 | sorland
# Processing Record 25 of Set 11 | capiibary
# Processing Record 26 of Set 11 | mocambique
# City not found. Skipping...
# Processing Record 27 of Set 11 | chomun
# City not found. Skipping...
# Processing Record 28 of Set 11 | ubinskoye
# Processing Record 29 of Set 11 | sovetskiy
# Processing Record 30 of Set 11 | komsomolskiy
# Processing Record 31 of Set 11 | yabelo
# Processing Record 32 of Set 11 | mporokoso
# Processing Record 33 of Set 11 | gubkinskiy
# Processing Record 34 of Set 11 | malanville
# Processing Record 35 of Set 11 | maiduguri
# Processing Record 36 of Set 11 | shache
# Processing Record 37 of Set 11 | rafraf
# Processing Record 38 of Set 11 | adelaide
# Processing Record 39 of Set 11 | teguise
# Processing Record 40 of Set 11 | hearst
# Processing Record 41 of Set 11 | oktyabrskoye
# Processing Record 42 of Set 11 | porbandar
# Processing Record 43 of Set 11 | jahrom
# City not found. Skipping...
# Processing Record 44 of Set 11 | chimoio
# Processing Record 45 of Set 11 | gualaquiza
# Processing Record 46 of Set 11 | guarapari
# Processing Record 47 of Set 11 | desenzano del garda
# Processing Record 48 of Set 11 | salamiyah
# Processing Record 49 of Set 11 | weligama
# Processing Record 50 of Set 11 | visby
# Processing Record 1 of Set 12 | punta de piedra
# Processing Record 2 of Set 12 | antalaha
# Processing Record 3 of Set 12 | barroualie
# City not found. Skipping...
# Processing Record 4 of Set 12 | campina verde
# Processing Record 5 of Set 12 | buenaventura
# Processing Record 6 of Set 12 | tchibanga
# Processing Record 7 of Set 12 | puerto leguizamo
# Processing Record 8 of Set 12 | othaya
# Processing Record 9 of Set 12 | shebekino
# Processing Record 10 of Set 12 | lokosovo
# Processing Record 11 of Set 12 | eyl
# Processing Record 12 of Set 12 | primore
# City not found. Skipping...
# Processing Record 13 of Set 12 | samoded
# Processing Record 14 of Set 12 | belfast
# Processing Record 15 of Set 12 | belyy yar
# Processing Record 16 of Set 12 | iskateley
# Processing Record 17 of Set 12 | buchmany
# Processing Record 18 of Set 12 | vyborg
# Processing Record 19 of Set 12 | ystad
# Processing Record 20 of Set 12 | vage
# Processing Record 21 of Set 12 | tabou
# Processing Record 22 of Set 12 | novyye lyady
# Processing Record 23 of Set 12 | zanjan
# Processing Record 24 of Set 12 | gboko
# Processing Record 25 of Set 12 | general pico
# Processing Record 26 of Set 12 | yarmouth
# Processing Record 27 of Set 12 | harrisonburg
# Processing Record 28 of Set 12 | manavalakurichi
# Processing Record 29 of Set 12 | boke
# Processing Record 30 of Set 12 | cap-aux-meules
# Processing Record 31 of Set 12 | cienfuegos
# Processing Record 32 of Set 12 | guadalupe
# Processing Record 33 of Set 12 | ulagan
# Processing Record 34 of Set 12 | inta
# Processing Record 35 of Set 12 | mananara
# Processing Record 36 of Set 12 | sulina
# Processing Record 37 of Set 12 | armacao de pera
# Processing Record 38 of Set 12 | kapuskasing
# Processing Record 39 of Set 12 | marandahalli
# Processing Record 40 of Set 12 | kleck
# City not found. Skipping...
# Processing Record 41 of Set 12 | karwar
# Processing Record 42 of Set 12 | tonstad
# Processing Record 43 of Set 12 | formoso do araguaia
# City not found. Skipping...
# Processing Record 44 of Set 12 | dabakala
# Processing Record 45 of Set 12 | srisailam
# Processing Record 46 of Set 12 | sozimskiy
# Processing Record 47 of Set 12 | llanes
# Processing Record 48 of Set 12 | ouango
# Processing Record 49 of Set 12 | los pozos
# Processing Record 50 of Set 12 | volga
# Processing Record 1 of Set 13 | takoradi
# Processing Record 2 of Set 13 | camapua
# Processing Record 3 of Set 13 | darnah
# Processing Record 4 of Set 13 | timra
# Processing Record 5 of Set 13 | asmar
# Processing Record 6 of Set 13 | nushki
# Processing Record 7 of Set 13 | makokou
# Processing Record 8 of Set 13 | elblag
# Processing Record 9 of Set 13 | punta alta
# Processing Record 10 of Set 13 | ozinki
# Processing Record 11 of Set 13 | salinas
# Processing Record 12 of Set 13 | bonaventure
# Processing Record 13 of Set 13 | munak
# Processing Record 14 of Set 13 | livingstone
# Processing Record 15 of Set 13 | shrewsbury
# Processing Record 16 of Set 13 | eutin
# Processing Record 17 of Set 13 | wahran
# City not found. Skipping...
# Processing Record 18 of Set 13 | isla mujeres
# Processing Record 19 of Set 13 | beyneu
# Processing Record 20 of Set 13 | oume
# Processing Record 21 of Set 13 | derzhavinsk
# Processing Record 22 of Set 13 | nelson
# Processing Record 23 of Set 13 | fez
# Processing Record 24 of Set 13 | najran
# Processing Record 25 of Set 13 | requena
# Processing Record 26 of Set 13 | manzil jamil
# City not found. Skipping...
# Processing Record 27 of Set 13 | kilrush
# Processing Record 28 of Set 13 | hlotse
# Processing Record 29 of Set 13 | ipixuna
# Processing Record 30 of Set 13 | alexandria
# Processing Record 31 of Set 13 | diamantino
# Processing Record 32 of Set 13 | salym
# Processing Record 33 of Set 13 | kabwe
# Processing Record 34 of Set 13 | monte azul
# Processing Record 35 of Set 13 | ambovombe
# Processing Record 36 of Set 13 | mahon
# Processing Record 37 of Set 13 | barabinsk
# Processing Record 38 of Set 13 | kalmar
# Processing Record 39 of Set 13 | jalu
# Processing Record 40 of Set 13 | grand-santi
# Processing Record 41 of Set 13 | muyezerskiy
# Processing Record 42 of Set 13 | teguldet
# Processing Record 43 of Set 13 | petauke
# Processing Record 44 of Set 13 | sinnamary
# Processing Record 45 of Set 13 | santa vitoria do palmar
# Processing Record 46 of Set 13 | savannah bight
# Processing Record 47 of Set 13 | umm kaddadah
# Processing Record 48 of Set 13 | westport
# Processing Record 49 of Set 13 | abu kamal
# Processing Record 50 of Set 13 | talnakh
# Processing Record 1 of Set 14 | zhob
# Processing Record 2 of Set 14 | huarmey
# Processing Record 3 of Set 14 | mrirt
# City not found. Skipping...
# Processing Record 4 of Set 14 | mahanoro
# Processing Record 5 of Set 14 | patan
# Processing Record 6 of Set 14 | ginir
# Processing Record 7 of Set 14 | abu dhabi
# Processing Record 8 of Set 14 | golden rock
# City not found. Skipping...
# Processing Record 9 of Set 14 | bocaiuva
# Processing Record 10 of Set 14 | zheleznodorozhnyy
# Processing Record 11 of Set 14 | canutama
# Processing Record 12 of Set 14 | leshukonskoye
# Processing Record 13 of Set 14 | vikevag
# Processing Record 14 of Set 14 | sena madureira
# Processing Record 15 of Set 14 | kasungu
# Processing Record 16 of Set 14 | veliki preslav
# Processing Record 17 of Set 14 | malinovoye ozero
# Processing Record 18 of Set 14 | kragujevac
# Processing Record 19 of Set 14 | connersville
# Processing Record 20 of Set 14 | kolondieba
# Processing Record 21 of Set 14 | honningsvag
# Processing Record 22 of Set 14 | tasbuget
# City not found. Skipping...
# Processing Record 23 of Set 14 | rudbar
# Processing Record 24 of Set 14 | kalisz
# Processing Record 25 of Set 14 | bundibugyo
# Processing Record 26 of Set 14 | dianopolis
# City not found. Skipping...
# Processing Record 27 of Set 14 | hualmay
# Processing Record 28 of Set 14 | tacoronte
# Processing Record 29 of Set 14 | angoche
# Processing Record 30 of Set 14 | ferme-neuve
# Processing Record 31 of Set 14 | nurota
# Processing Record 32 of Set 14 | surenavan
# Processing Record 33 of Set 14 | meulaboh
# Processing Record 34 of Set 14 | serebryansk
# Processing Record 35 of Set 14 | kuruman
# Processing Record 36 of Set 14 | puck
# Processing Record 37 of Set 14 | sorvag
# City not found. Skipping...
# Processing Record 38 of Set 14 | tzucacab
# Processing Record 39 of Set 14 | saryshagan
# City not found. Skipping...
# Processing Record 40 of Set 14 | misratah
# Processing Record 41 of Set 14 | alhandra
# Processing Record 42 of Set 14 | garagoa
# Processing Record 43 of Set 14 | manturovo
# Processing Record 44 of Set 14 | onguday
# Processing Record 45 of Set 14 | igdir
# Processing Record 46 of Set 14 | saint-hyacinthe
# Processing Record 47 of Set 14 | opuwo
# Processing Record 48 of Set 14 | calama
# Processing Record 49 of Set 14 | birigui
# Processing Record 50 of Set 14 | zhezkazgan
# Processing Record 1 of Set 15 | lethem
# Processing Record 2 of Set 15 | aden
# Processing Record 3 of Set 15 | mattru
# Processing Record 4 of Set 15 | sorata
# Processing Record 5 of Set 15 | maldonado
# Processing Record 6 of Set 15 | nanga eboko
# Processing Record 7 of Set 15 | villa bruzual
# Processing Record 8 of Set 15 | buqayq
# City not found. Skipping...
# Processing Record 9 of Set 15 | vossevangen
# Processing Record 10 of Set 15 | rio grande
# Processing Record 11 of Set 15 | chabahar
# Processing Record 12 of Set 15 | kassala
# Processing Record 13 of Set 15 | bure
# Processing Record 14 of Set 15 | lisala
# Processing Record 15 of Set 15 | pojuca
# Processing Record 16 of Set 15 | mabaruma
# Processing Record 17 of Set 15 | iquitos
# Processing Record 18 of Set 15 | senneterre
# Processing Record 19 of Set 15 | umm jarr
# City not found. Skipping...
# Processing Record 20 of Set 15 | kedrovyy
# Processing Record 21 of Set 15 | skjervoy
# Processing Record 22 of Set 15 | placido de castro
# Processing Record 23 of Set 15 | savelugu
# Processing Record 24 of Set 15 | seda
# Processing Record 25 of Set 15 | effingham
# Processing Record 26 of Set 15 | urubicha
# Processing Record 27 of Set 15 | ust-tsilma
# Processing Record 28 of Set 15 | thinadhoo
# Processing Record 29 of Set 15 | canto do buriti
# Processing Record 30 of Set 15 | pestovo
# Processing Record 31 of Set 15 | vyazma
# Processing Record 32 of Set 15 | yekaterinovka
# Processing Record 33 of Set 15 | zapolyarnyy
# Processing Record 34 of Set 15 | messina
# Processing Record 35 of Set 15 | camana
# Processing Record 36 of Set 15 | mizan teferi
# Processing Record 37 of Set 15 | basoko
# Processing Record 38 of Set 15 | palkaka
# City not found. Skipping...
# Processing Record 39 of Set 15 | mopipi
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 676

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#                 City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Punta Arenas -53.1500  -70.9167     46.51        76           0
# 1          Busselton -33.6500  115.3333     59.49        61          80
# 2            Ushuaia -54.8000  -68.3000     49.66        53          20
# 3            Qaanaaq  77.4840  -69.3632     -9.99        82          95
# 4              Beira -19.8436   34.8389     87.89        66          20
# 5             Hwange -18.3693   26.5019     93.45        24           9
# 6  Tournon-Sur-Rhone  45.0667    4.8333     56.86        76         100
# 7             Marzuq  14.4000   46.4667     81.01        21           7
# 8         Bredasdorp -34.5322   20.0403     67.77        46         100
# 9            Voyvozh  62.8920   54.9635      0.27        92          14
#
#    Wind Speed Country Weather Description
# 0        6.91      CL           clear sky
# 1       17.34      AU       broken clouds
# 2       12.66      AR          few clouds
# 3        5.68      GL     overcast clouds
# 4        2.30      MZ          few clouds
# 5        4.81      ZW           clear sky
# 6       12.66      FR     overcast clouds
# 7        7.23      YE           clear sky
# 8        8.77      ZA     overcast clouds
# 9        3.78      RU          few clouds

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Weather Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Weather Description"]

# Recreate the DataFrame by using the new column order
city_data_df = city_data_df[new_column_order]

# Display sample data
city_data_df.head(10)
# Out:
#                 City Country      Lat       Lng  Max Temp  Humidity  \
# 0       Punta Arenas      CL -53.1500  -70.9167     46.51        76
# 1          Busselton      AU -33.6500  115.3333     59.49        61
# 2            Ushuaia      AR -54.8000  -68.3000     49.66        53
# 3            Qaanaaq      GL  77.4840  -69.3632     -9.99        82
# 4              Beira      MZ -19.8436   34.8389     87.89        66
# 5             Hwange      ZW -18.3693   26.5019     93.45        24
# 6  Tournon-Sur-Rhone      FR  45.0667    4.8333     56.86        76
# 7             Marzuq      YE  14.4000   46.4667     81.01        21
# 8         Bredasdorp      ZA -34.5322   20.0403     67.77        46
# 9            Voyvozh      RU  62.8920   54.9635      0.27        92
#
#    Cloudiness  Wind Speed Weather Description
# 0           0        6.91           clear sky
# 1          80       17.34       broken clouds
# 2          20       12.66          few clouds
# 3          95        5.68     overcast clouds
# 4          20        2.30          few clouds
# 5           9        4.81           clear sky
# 6         100       12.66     overcast clouds
# 7           7        7.23           clear sky
# 8         100        8.77     overcast clouds
# 9          14        3.78          few clouds

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Weather Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = "WeatherPy_Database.csv"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_data_file, index_label="City_ID")
